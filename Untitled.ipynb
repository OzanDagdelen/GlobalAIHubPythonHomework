# %%
a=input("1. sayısı giriniz..: ")
b=input("\n2. sayısı giriniz..: ")
c=input("\n3. sayısı giriniz..: ")
d=input("\n4. sayısı giriniz..: ")
e=input("\n5. sayısı giriniz..: ")

print("1. sayınız {}\n2. sayınız {}\n3. sayınız {}\n4. sayınız {}\n5. sayınız {}\n".format(a,b,c,d,e))
print("1. sayının türü ",type(a))
print("2. sayının türü ",type(b))
print("3. sayının türü ",type(c))
print("4. sayının türü ",type(d))
print("5. sayının türü ",type(e))
# Out:
# 1. sayısı giriniz..: 7
#
# 2. sayısı giriniz..: 8
#
# 3. sayısı giriniz..: 9
#
# 4. sayısı giriniz..: 10
#
# 5. sayısı giriniz..: 11
# 1. sayınız 7
# 2. sayınız 8
# 3. sayınız 9
# 4. sayınız 10
# 5. sayınız 11
#
# 1. sayının türü  <class 'str'>
# 2. sayının türü  <class 'str'>
# 3. sayının türü  <class 'str'>
# 4. sayının türü  <class 'str'>
# 5. sayının türü  <class 'str'>
